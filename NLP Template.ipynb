# %%
# Import libraries

import pandas as pd
import nltk
import numpy as np
from nltk.tokenize import PunktSentenceTokenizer,RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from scipy import sparse
from sklearn.metrics.pairwise import pairwise_distances, cosine_similarity
import warnings
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.feature_extraction import text

# %%
#to ignore deprecation warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [raw]
# Processed_country have following column
# name, continent, review(scraped from website using scraping_data code),
# terrain(Excel Vlookup) - https://www.nationmaster.com/country-info/stats/Geography/Terrain#2013
# Zones(Excel Vlookup) - https://www.google.com/maps/d/edit?mid=1Npbd1eeMQad4S6xoBNBdZglMZux5oE6n&usp=sharing

# %%
df = pd.read_csv("./processed_country.csv", encoding='latin-1')

# %%
df.head()
# Out:
#             name      continent  \
# 0        armenia         europe
# 1  czechrepublic         europe
# 2           chad         africa
# 3         cyprus         europe
# 4        ecuador  south-america
#
#                                               review  \
# 0   It might be a small nation, but Armenia is bi...
# 1   A historic jewel at the heart of Europe, the ...
# 2  From the natural wonders of the Sahara Desert ...
# 3  The legendary birthplace of Aphrodite, Cyprus ...
# 4   Tiny by South American standards, Ecuador is ...
#
#                                              terrain                     Zones
# 0  Armenian Highland with mountains; little fores...  Non listed third country
# 1  Bohemia in the west consists of rolling plains...                        EU
# 2  broad, arid plains in center, desert in north,...  Non listed third country
# 3  central plain with mountains to north and sout...                        EU
# 4  coastal plain (costa), inter-Andean central hi...  Non listed third country

# %%
df["text"] = df["review"]

# %%
df = df[["name","continent","terrain", "Zones"]]

# %%
df
# Out:
#                 name      continent  \
# 0            armenia         europe
# 1      czechrepublic         europe
# 2               chad         africa
# 3             cyprus         europe
# 4            ecuador  south-america
# ..               ...            ...
# 194            yemen    middle-east
# 195           zambia         africa
# 196         zimbabwe         africa
# 197  northernireland         europe
# 198             guam        oceania
#
#                                                terrain  \
# 0    Armenian Highland with mountains; little fores...
# 1    Bohemia in the west consists of rolling plains...
# 2    broad, arid plains in center, desert in north,...
# 3    central plain with mountains to north and sout...
# 4    coastal plain (costa), inter-Andean central hi...
# ..                                                 ...
# 194  narrow coastal plain backed by flat-topped hil...
# 195  mostly high plateau with some hills and mountains
# 196  mostly high plateau with higher central platea...
# 197  mostly level to rolling interior plain surroun...
# 198  volcanic origin, surrounded by coral reefs; re...
#
#                             Zones
# 0        Non listed third country
# 1                              EU
# 2        Non listed third country
# 3                              EU
# 4        Non listed third country
# ..                            ...
# 194      Non listed third country
# 195      Non listed third country
# 196      Non listed third country
# 197  EU with tighter requirements
# 198          Listed third country
#
# [199 rows x 4 columns]

# %%
#Lowercasing
df["lower_text"]= df["terrain"].apply(lambda x : x.lower())

# %%
# tokenize
tokenizer = RegexpTokenizer(r'\w+')
df["tokenized_text"] = df["lower_text"].apply(lambda row: tokenizer.tokenize(row))

# %%
# lemmatize 
wnl = nltk.WordNetLemmatizer()

# %%
def lem(lst):
    list1=list()
    for i in lst : 
        list1.append(wnl.lemmatize(i))
    return list1

# %%
df["lemmatized_text"]=df["tokenized_text"].apply(lambda x : lem(x))

# %%
df.iloc[0]["lower_text"]
# Out:
# 'armenian highland with mountains; little forest land; fast flowing rivers; good soil in aras river valley'

# %%
df.iloc[0]["tokenized_text"]
# Out:
# ['armenian',
#  'highland',
#  'with',
#  'mountains',
#  'little',
#  'forest',
#  'land',
#  'fast',
#  'flowing',
#  'rivers',
#  'good',
#  'soil',
#  'in',
#  'aras',
#  'river',
#  'valley']

# %%
df.iloc[0]["lemmatized_text"]
# Out:
# ['armenian',
#  'highland',
#  'with',
#  'mountain',
#  'little',
#  'forest',
#  'land',
#  'fast',
#  'flowing',
#  'river',
#  'good',
#  'soil',
#  'in',
#  'ara',
#  'river',
#  'valley']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

my_additional_stop_words = ['acute', 'good', 'great', 'really', 'just', 'nice', 
                            'like', 'day', 'beautiful', 'visit', 'time', 'don',
                            'did', 'place', 'didn', 'did', 'tour', 'sydney','pm', 'the',
                            'lot', '00', 'inside', 'doesn','going','mostly', 'origin',
                            'right', '15']
stop_words = text.ENGLISH_STOP_WORDS.union(my_additional_stop_words)


tfidf_vectorizer = TfidfVectorizer(stop_words=stop_words, strip_accents='unicode', norm='l2',lowercase=True)

# %%
X=[" ".join(text) for text in df["lemmatized_text"].values]
tfidf_matrix=tfidf_vectorizer.fit_transform(X)

# %%
tfidf_matrix.shape
# Out:
# (199, 409)

# %%
similarity_matrix = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
# Create a pandas series with movie titles as indices and indices as series values 
indices = pd.Series(df.index, index=df['name']).drop_duplicates()

# %%
indices
# Out:
# name
# armenia              0
# czechrepublic        1
# chad                 2
# cyprus               3
# ecuador              4
#                   ...
# yemen              194
# zambia             195
# zimbabwe           196
# northernireland    197
# guam               198
# Length: 199, dtype: int64

# %%
title='zambia'

# Get the index corresponding to movie title
index = indices[title]

# Get the cosine similarity scores 
similarity_scores = list(enumerate(similarity_matrix[index]))


# Sort the similarity scores in descending order
sorted_similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)


# Top-10 most similar movie scores
top_10_movies_scores = sorted_similarity_scores[1:11]

# %%
# Get movie indices
top_10_movie_indices=[]
for i in top_10_movies_scores:
    top_10_movie_indices.append(i[0])
    
# Top 10 recommende movie
df['name'].iloc[top_10_movie_indices]
# Out:
# 114               mexico
# 196             zimbabwe
# 44                 china
# 105           madagascar
# 98               lesotho
# 33               algeria
# 120           mozambique
# 179    trinidadandtobago
# 181               turkey
# 95                  laos
# Name: name, dtype: object

# %%
from sklearn.metrics.pairwise import linear_kernel
cosine_similarities = linear_kernel(tf_idf[-1], tf_idf[0:199]).flatten()

# %%
df['similarity2']=cosine_similarities

# %%
df.sort_values(by='similarity2',ascending=False)
# Out:
#            name      continent  \
# 198        guam        oceania
# 71    guatemala  north-america
# 191     vanuatu        oceania
# 41         fiji        oceania
# 56     dominica      caribbean
# ..          ...            ...
# 94   kyrgyzstan           asia
# 87        japan           asia
# 75        haiti      caribbean
# 39       bhutan           asia
# 47    easttimor           asia
#
#                                                terrain  \
# 198  volcanic origin, surrounded by coral reefs; re...
# 71   mostly mountains with narrow coastal plains an...
# 191  mostly mountainous islands of volcanic origin;...
# 41                 mostly mountains of volcanic origin
# 56                 rugged mountains of volcanic origin
# ..                                                 ...
# 94   peaks of Tien Shan and associated valleys and ...
# 87                       mostly rugged and mountainous
# 75                        mostly rough and mountainous
# 39   mostly mountainous with some fertile valleys a...
# 47                                         mountainous
#
#                         Zones  \
# 198      Listed third country
# 71   Non listed third country
# 191      Listed third country
# 41       Listed third country
# 56   Non listed third country
# ..                        ...
# 94   Non listed third country
# 87       Listed third country
# 75   Non listed third country
# 39   Non listed third country
# 47   Non listed third country
#
#                                             lower_text  \
# 198  volcanic origin, surrounded by coral reefs; re...
# 71   mostly mountains with narrow coastal plains an...
# 191  mostly mountainous islands of volcanic origin;...
# 41                 mostly mountains of volcanic origin
# 56                 rugged mountains of volcanic origin
# ..                                                 ...
# 94   peaks of tien shan and associated valleys and ...
# 87                       mostly rugged and mountainous
# 75                        mostly rough and mountainous
# 39   mostly mountainous with some fertile valleys a...
# 47                                         mountainous
#
#                                         tokenized_text  \
# 198  [volcanic, origin, surrounded, by, coral, reef...
# 71   [mostly, mountains, with, narrow, coastal, pla...
# 191  [mostly, mountainous, islands, of, volcanic, o...
# 41           [mostly, mountains, of, volcanic, origin]
# 56           [rugged, mountains, of, volcanic, origin]
# ..                                                 ...
# 94   [peaks, of, tien, shan, and, associated, valle...
# 87                  [mostly, rugged, and, mountainous]
# 75                   [mostly, rough, and, mountainous]
# 39   [mostly, mountainous, with, some, fertile, val...
# 47                                       [mountainous]
#
#                                        lemmatized_text  similarity  \
# 198  [volcanic, origin, surrounded, by, coral, reef...    1.000000
# 71   [mostly, mountain, with, narrow, coastal, plai...    0.219783
# 191  [mostly, mountainous, island, of, volcanic, or...    0.205215
# 41            [mostly, mountain, of, volcanic, origin]    0.189742
# 56            [rugged, mountain, of, volcanic, origin]    0.170735
# ..                                                 ...         ...
# 94   [peak, of, tien, shan, and, associated, valley...    0.000000
# 87                  [mostly, rugged, and, mountainous]    0.000000
# 75                   [mostly, rough, and, mountainous]    0.000000
# 39   [mostly, mountainous, with, some, fertile, val...    0.000000
# 47                                       [mountainous]    0.000000
#
#      similarity2
# 198     1.000000
# 71      0.356362
# 191     0.245828
# 41      0.198160
# 56      0.160597
# ..           ...
# 94      0.000000
# 87      0.000000
# 75      0.000000
# 39      0.000000
# 47      0.000000
#
# [199 rows x 9 columns]

# %%
a = df.sort_values(by=['Zones','similarity2'],ascending=False)

# %%
a[a.Zones == "Non listed third country"].head(20)
# Out:
#                  name      continent  \
# 71          guatemala  north-america
# 105        madagascar         africa
# 91           kiribati        oceania
# 30             brazil  south-america
# 11           anguilla      caribbean
# 16             belize  north-america
# 60            comoros         africa
# 76           honduras  north-america
# 111   marshallislands        oceania
# 156        seychelles         africa
# 9            cameroon         africa
# 57          capeverde         africa
# 36           cambodia           asia
# 43         elsalvador  north-america
# 164        southkorea           asia
# 33            algeria         africa
# 123             nauru        oceania
# 169          suriname  south-america
# 118        montenegro         europe
# 6    equatorialguinea         africa
#
#                                                terrain  \
# 71   mostly mountains with narrow coastal plains an...
# 105  narrow coastal plain, high plateau and mountai...
# 91   mostly low-lying coral atolls surrounded by ex...
# 30   mostly flat to rolling lowlands in north; some...
# 11    flat and low-lying island of coral and limestone
# 16   flat, swampy coastal plain; low mountains in s...
# 60   volcanic islands, interiors vary from steep mo...
# 76   mostly mountains in interior, narrow coastal p...
# 111               low coral limestone and sand islands
# 156  Mahe Group is granitic, narrow coastal strip, ...
# 9    diverse, with coastal plain in southwest, diss...
# 57                      steep, rugged, rocky, volcanic
# 36   mostly low, flat plains; mountains in southwes...
# 43   mostly mountains with narrow coastal belt and ...
# 164  mostly hills and mountains; wide coastal plain...
# 33   mostly high plateau and desert; some mountains...
# 123  sandy beach rises to fertile ring around raise...
# 169  mostly rolling hills; narrow coastal plain wit...
# 118  highly indented coastline with narrow coastal ...
# 6    coastal plains rise to interior hills; islands...
#
#                         Zones  \
# 71   Non listed third country
# 105  Non listed third country
# 91   Non listed third country
# 30   Non listed third country
# 11   Non listed third country
# 16   Non listed third country
# 60   Non listed third country
# 76   Non listed third country
# 111  Non listed third country
# 156  Non listed third country
# 9    Non listed third country
# 57   Non listed third country
# 36   Non listed third country
# 43   Non listed third country
# 164  Non listed third country
# 33   Non listed third country
# 123  Non listed third country
# 169  Non listed third country
# 118  Non listed third country
# 6    Non listed third country
#
#                                             lower_text  \
# 71   mostly mountains with narrow coastal plains an...
# 105  narrow coastal plain, high plateau and mountai...
# 91   mostly low-lying coral atolls surrounded by ex...
# 30   mostly flat to rolling lowlands in north; some...
# 11    flat and low-lying island of coral and limestone
# 16   flat, swampy coastal plain; low mountains in s...
# 60   volcanic islands, interiors vary from steep mo...
# 76   mostly mountains in interior, narrow coastal p...
# 111               low coral limestone and sand islands
# 156  mahe group is granitic, narrow coastal strip, ...
# 9    diverse, with coastal plain in southwest, diss...
# 57                      steep, rugged, rocky, volcanic
# 36   mostly low, flat plains; mountains in southwes...
# 43   mostly mountains with narrow coastal belt and ...
# 164  mostly hills and mountains; wide coastal plain...
# 33   mostly high plateau and desert; some mountains...
# 123  sandy beach rises to fertile ring around raise...
# 169  mostly rolling hills; narrow coastal plain wit...
# 118  highly indented coastline with narrow coastal ...
# 6    coastal plains rise to interior hills; islands...
#
#                                         tokenized_text  \
# 71   [mostly, mountains, with, narrow, coastal, pla...
# 105  [narrow, coastal, plain, high, plateau, and, m...
# 91   [mostly, low, lying, coral, atolls, surrounded...
# 30   [mostly, flat, to, rolling, lowlands, in, nort...
# 11   [flat, and, low, lying, island, of, coral, and...
# 16   [flat, swampy, coastal, plain, low, mountains,...
# 60   [volcanic, islands, interiors, vary, from, ste...
# 76   [mostly, mountains, in, interior, narrow, coas...
# 111        [low, coral, limestone, and, sand, islands]
# 156  [mahe, group, is, granitic, narrow, coastal, s...
# 9    [diverse, with, coastal, plain, in, southwest,...
# 57                    [steep, rugged, rocky, volcanic]
# 36   [mostly, low, flat, plains, mountains, in, sou...
# 43   [mostly, mountains, with, narrow, coastal, bel...
# 164  [mostly, hills, and, mountains, wide, coastal,...
# 33   [mostly, high, plateau, and, desert, some, mou...
# 123  [sandy, beach, rises, to, fertile, ring, aroun...
# 169  [mostly, rolling, hills, narrow, coastal, plai...
# 118  [highly, indented, coastline, with, narrow, co...
# 6    [coastal, plains, rise, to, interior, hills, i...
#
#                                        lemmatized_text  similarity  \
# 71   [mostly, mountain, with, narrow, coastal, plai...    0.219783
# 105  [narrow, coastal, plain, high, plateau, and, m...    0.153128
# 91   [mostly, low, lying, coral, atoll, surrounded,...    0.104268
# 30   [mostly, flat, to, rolling, lowland, in, north...    0.103430
# 11   [flat, and, low, lying, island, of, coral, and...    0.087336
# 16   [flat, swampy, coastal, plain, low, mountain, ...    0.139608
# 60   [volcanic, island, interior, vary, from, steep...    0.115062
# 76   [mostly, mountain, in, interior, narrow, coast...    0.126543
# 111         [low, coral, limestone, and, sand, island]    0.083605
# 156  [mahe, group, is, granitic, narrow, coastal, s...    0.090945
# 9    [diverse, with, coastal, plain, in, southwest,...    0.164985
# 57                    [steep, rugged, rocky, volcanic]    0.076946
# 36   [mostly, low, flat, plain, mountain, in, south...    0.058302
# 43   [mostly, mountain, with, narrow, coastal, belt...    0.096185
# 164  [mostly, hill, and, mountain, wide, coastal, p...    0.075253
# 33   [mostly, high, plateau, and, desert, some, mou...    0.077483
# 123  [sandy, beach, rise, to, fertile, ring, around...    0.110748
# 169  [mostly, rolling, hill, narrow, coastal, plain...    0.113115
# 118  [highly, indented, coastline, with, narrow, co...    0.093079
# 6    [coastal, plain, rise, to, interior, hill, isl...    0.074850
#
#      similarity2
# 71      0.356362
# 105     0.334048
# 91      0.276476
# 30      0.255980
# 11      0.254460
# 16      0.238954
# 60      0.236615
# 76      0.231223
# 111     0.231055
# 156     0.230914
# 9       0.226910
# 57      0.206334
# 36      0.198629
# 43      0.197428
# 164     0.194482
# 33      0.193729
# 123     0.191478
# 169     0.191422
# 118     0.190986
# 6       0.188286

# %%
def generate_recomendations(df,film_name,input_films_rated,top_results=5,cat=categories):
    print("Movie Recommender by B.Kurka:")
    print("User name: " + "Favorite Movie:", film_name+'\n\n')
    print("Films you might enjooy based that you watched", film_name)
    ## Item Rating Based Cosine Similarity
    cos_sim = item_based_recom(df,film_name)
    display(cos_sim[1:top_results+1])
    
    print("***********************************************************************************************\n")
    print("Films you might enjooy with similar genre then", film_name) 
    display(item_and_genre_based_recom(item_based_recom(df,film_name),movies,categories)\
            .sort_values('cosine_sim',ascending=False)[top_results:]\
            .sort_values('genre_similarity',ascending=False)[:top_results])
   
    print("***********************************************************************************************\n")
    print("Flims reccomended for you:")
    a = user_based_recom(df,input_films_rated,user_id)[0:25]
    
    display(user_based_recom(df,input_films_rated,user_id)[0:5])
#     display()

    return None
    
generate_recomendations(df,film_name,films_rated,5)
